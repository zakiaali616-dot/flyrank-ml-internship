# %% [markdown]
# ## Evidence from the Starter Dataset
#
# The starter ML pipeline produced the following results:
#
# - Baseline Precision@50 = **0.240**
# - Random Forest Precision@50 = **0.680**
# - The Random Forest model performed about **2.8× better** than the baseline rule on Precision@50.
#
# These results suggest that, on the starter dataset, the learned model ranked pages for review more effectively than the hand-written baseline rule.

# %% [markdown]
# ## Decision
# Decide whether improving search ranking is likely to increase click-through rate (CTR) for a page.
#
# ## Action
# If higher rankings are associated with higher CTR, prioritize improving the ranking of important pages through SEO improvements.
#
# ## Cost of a Wrong Decision
# If the conclusion is wrong, time and resources may be spent improving rankings without increasing CTR, while more effective opportunities could be missed.
#
# ## Why Data Can Help
# The starter dataset contains search position, CTR, impressions, and clicks. These metrics can be analyzed to determine whether better rankings are associated with higher CTR.

# %% [markdown]
# # Week 1 Research Question
#
# **Research Question:** Does a higher search ranking lead to a higher click-through rate (CTR)?
